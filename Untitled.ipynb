# %%
import csv
import pandas as pd

# %%
pd.set_option('display.max_columns', 40)

# %%
df_train = pd.read_csv('data/iwakitaira_train_data.csv', encoding="SHIFT_JIS", header=0, nrows=None)
# Out:
# C:\Users\taker\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_train
# Out:
#            date       place  race_num  predict koukiai  evaluation  bracket  \
# 0      20120102  iwakitaira         1      NaN     NaN         NaN        1
# 1      20120102  iwakitaira         1      NaN     NaN         NaN        2
# 2      20120102  iwakitaira         1      NaN     NaN         NaN        3
# 3      20120102  iwakitaira         1      NaN     NaN         NaN        4
# 4      20120102  iwakitaira         1      NaN     NaN         NaN        4
# 5      20120102  iwakitaira         1      NaN     NaN         NaN        5
# 6      20120102  iwakitaira         1      NaN     NaN         NaN        5
# 7      20120102  iwakitaira         1      NaN     NaN         NaN        6
# 8      20120102  iwakitaira         1      NaN     NaN         NaN        6
# 9      20120102  iwakitaira         2      NaN     NaN         NaN        1
# 10     20120102  iwakitaira         2      NaN     NaN         NaN        2
# ...

# %%
df_train.columns
# Out:
# Index(['date', 'place', 'race_num', 'predict', 'koukiai', 'evaluation',
#        'bracket', 'car_num', 'name', 'prefecture', 'age', 'period', 'rank',
#        'leg', 'gear', 'racing piont', 'S', 'B', 'Nige', 'Maki', 'Sashi', 'Ma',
#        '1st', '2nd', '3rd', 'Chakugai', 'win', '2ren', '3ren', 'result'],
#       dtype='object')

# %%
for column in df_train.columns:
    print(column)
    print(df_train[column].unique())
# Out:
# date
# [20120102 20120103 20120104 20120121 20120122 20120123 20120124 20120215
#  20120216 20120217 20120223 20120224 20120225 20120310 20120311 20120312
#  20120321 20120322 20120323 20120412 20120413 20120414 20120518 20120519
#  20120520 20120602 20120603 20120604 20120608 20120609 20120610 20120713
#  20120714 20120715 20120810 20120811 20120812 20120907 20120908 20120909
#  20121025 20121026 20121027 20121103 20121104 20121105 20121109 20121110
#  20121111 20121129 20121130 20121201 20121208 20121209 20121210 20121222
#  20121223 20121224 20130102 20130103 20130104 20130112 20130113 20130114
#  20130119 20130120 20130121 20130216 20130217 20130218 20130307 20130308
#  20130309 20130310 20130328 20130329 20130330 20130407 20130408 20130409
#  20130507 20130508 20130509 20130606 20130607 20130608 20130624 20130625
#  20130626 20130712 20130713 20130714 20130802 20130803 20130818 20130819
#  20130820 20130922 20130923 20130924 20131012 20131013 20131014 20131030
# ...
