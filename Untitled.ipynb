# %%
import pandas as pd
import numpy as np

# %%
file_name = 'crawl_20180904-195042_Crawler.csv'
race_record = pd.read_csv(file_name)

# %%
race_record
# Out:
#       Unnamed: 0  date    ID     name  age  term  prefecture  rank  \
# 0              0     0  4043  桐 本 康 臣   37    85          24     2
# 1              1     0  4533  峰 重 侑 治   28   103          33     3
# 2              2     0  4859  染 川 直 哉   29   116          11     3
# 3              3     0  4601  森 野 正 弘   32   106          35     2
# 4              4     0  4203  小 倉 康 典   35    91          10     3
# 5              5     0  4465  大 西   賢   31   101          13     3
# 6              0     0  3827  今 泉   徹   44    78          10     3
# 7              1     0  3561  池 田 真 治   49    70          33     3
# 8              2     0  4587  木 田 峰由季   26   105          18     2
# 9              3     0  4009  小 林 一 樹   38    84          35     3
# 10             4     0  4860  伏 見   卓   29   116          23     3
# 11             5     0  4944  田 代 達 也   26   119          13     4
# 12             0     0  3865  関     道   42    79          11     3
# ...
